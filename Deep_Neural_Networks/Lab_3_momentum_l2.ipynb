# %% [markdown]
# In this lab, you will implement some of the techniques discussed in the lecture.
#
# Below you are given a solution to the previous scenario. Note that it has two serious drawbacks:
#  * The output predictions do not sum up to one (i.e. it does not return a distribution) even though the images always contain exactly one digit.
#  * It uses MSE coupled with output sigmoid which can lead to saturation and slow convergence
#
# **Task 1.** Use softmax instead of coordinate-wise sigmoid and use log-loss instead of MSE. Test to see if this improves convergence. Hint: When implementing backprop it might be easier to consider these two function as a single block and not even compute the gradient over the softmax values.
#
# **Task 2.** Implement L2 regularization and add momentum to the SGD algorithm. Play with different amounts of regularization and momentum. See if this improves accuracy/convergence.
#
# **Task 3 (optional).** Implement Adagrad, dropout and some simple data augmentations (e.g. tiny rotations/shifts etc.). Again, test to see how these changes improve accuracy/convergence.
#
# **Task 4.** Try adding extra layers to the network. Again, test how the changes you introduced affect accuracy/convergence. As a start, you can try this architecture: [784,100,30,10]

# %%
import random
import numpy as np
from torchvision import datasets, transforms

# %%
# Let's read the mnist dataset

def load_mnist(path='.'):
    train_set = datasets.MNIST(path, train=True, download=True)
    x_train = train_set.data.numpy()
    _y_train = train_set.targets.numpy()
    
    test_set = datasets.MNIST(path, train=False, download=True)
    x_test = test_set.data.numpy()
    _y_test = test_set.targets.numpy()
    
    x_train = x_train.reshape((x_train.shape[0],28*28)) / 255.
    x_test = x_test.reshape((x_test.shape[0],28*28)) / 255.

    y_train = np.zeros((_y_train.shape[0], 10))
    y_train[np.arange(_y_train.shape[0]), _y_train] = 1
    
    y_test = np.zeros((_y_test.shape[0], 10))
    y_test[np.arange(_y_test.shape[0]), _y_test] = 1

    return (x_train, y_train), (x_test, y_test)

(x_train, y_train), (x_test, y_test) = load_mnist()
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to ./MNIST/raw/train-images-idx3-ubyte.gz
#   0%|          | 0/9912422 [00:00<?, ?it/s]
# Extracting ./MNIST/raw/train-images-idx3-ubyte.gz to ./MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to ./MNIST/raw/train-labels-idx1-ubyte.gz
#   0%|          | 0/28881 [00:00<?, ?it/s]
# Extracting ./MNIST/raw/train-labels-idx1-ubyte.gz to ./MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to ./MNIST/raw/t10k-images-idx3-ubyte.gz
#   0%|          | 0/1648877 [00:00<?, ?it/s]
# Extracting ./MNIST/raw/t10k-images-idx3-ubyte.gz to ./MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to ./MNIST/raw/t10k-labels-idx1-ubyte.gz
#   0%|          | 0/4542 [00:00<?, ?it/s]
# Extracting ./MNIST/raw/t10k-labels-idx1-ubyte.gz to ./MNIST/raw

# %%
def sigmoid(z):
    return 1.0/(1.0+np.exp(-z))

def sigmoid_prime(z):
    # Derivative of the sigmoid
    return sigmoid(z)*(1-sigmoid(z))

def softmax(x):
    exps = np.exp(x)
    assert exps.shape[1] == np.sum(exps,axis=0).reshape(1,-1).shape[1]
    return exps/(np.sum(exps,axis=0).reshape(1,-1))

# %%
class Network(object):
    def __init__(self, sizes):
        # initialize biases and weights with random normal distr.
        # weights are indexed by target node first
        self.num_layers = len(sizes)
        self.sizes = sizes
        self.biases = [np.random.randn(y, 1) for y in sizes[1:]]
        self.biases_accumulator = [np.zeros([y, 1]) for y in sizes[1:]]
        self.weights = [np.random.randn(y, x) 
                        for x, y in zip(sizes[:-1], sizes[1:])]
        self.weights_accumulator = [np.zeros([y, x]) 
                        for x, y in zip(sizes[:-1], sizes[1:])]
        
    def feedforward(self, a):
        # Run the network on a batch
        a = a.T
        for b, w in zip(self.biases[:-1], self.weights[:-1]):
            a = sigmoid(np.matmul(w, a)+b)
        a = softmax(np.matmul(self.weights[-1], a)+self.biases[-1])
        return a
    
    def update_mini_batch(self, mini_batch, eta, momentum=0, l2=0):
        # Update networks weights and biases by applying a single step
        # of gradient descent using backpropagation to compute the gradient.
        # The gradient is computed for a mini_batch which is as in tensorflow API.
        # eta is the learning rate      
        nabla_b, nabla_w = self.backprop(mini_batch[0].T,mini_batch[1].T)
        
        self.weights_accumulator = [momentum*w-(eta/len(mini_batch[0]))*nw 
                                    for w, nw in zip(self.weights_accumulator, nabla_w)]            
        self.weights = [(1.0 - l2)*w + wa for w, wa in zip(self.weights, self.weights_accumulator)]
        
        self.biases_accumulator = [momentum*b-(eta/len(mini_batch[0]))*nb 
                       for b, nb in zip(self.biases_accumulator, nabla_b)]
        self.biases = [b+ba for b, ba in zip(self.biases, self.biases_accumulator)]
        
    def backprop(self, x, y):
        # For a single input (x,y) return a pair of lists.
        # First contains gradients over biases, second over weights.
        g = x
        gs = [g] # list to store all the gs, layer by layer
        fs = [] # list to store all the fs, layer by layer
        for b, w in zip(self.biases, self.weights):
            f = np.dot(w, g)+b
            fs.append(f)
            g = sigmoid(f)
            gs.append(g)
        # backward pass <- both steps at once
        dLdg = self.cost_derivative(gs[-1], y)
        dLdfs = []
        for w,g in reversed(list(zip(self.weights,gs[1:]))):
            dLdf = np.multiply(dLdg,np.multiply(g,1-g))
            dLdfs.append(dLdf)
            dLdg = np.matmul(w.T, dLdf)
        
        dLdWs = [np.matmul(dLdf,g.T) for dLdf,g in zip(reversed(dLdfs),gs[:-1])] 
        dLdBs = [np.sum(dLdf,axis=1).reshape(dLdf.shape[0],1) for dLdf in reversed(dLdfs)] 
        return (dLdBs,dLdWs)

    def evaluate(self, test_data):
        # Count the number of correct answers for test_data
        pred = np.argmax(self.feedforward(test_data[0]),axis=0)
        corr = np.argmax(test_data[1],axis=1).T
        return np.mean(pred==corr)
    
    def cost_derivative(self, output_activations, y):
        return (output_activations-y) 
    
    def SGD(self, training_data, epochs, mini_batch_size, eta, momentum=0, l2=0, test_data=None):
        x_train, y_train = training_data
        if test_data:
            x_test, y_test = test_data
        for j in range(epochs):
            for i in range(x_train.shape[0] // mini_batch_size):
                x_mini_batch = x_train[(mini_batch_size*i):(mini_batch_size*(i+1))]
                y_mini_batch = y_train[(mini_batch_size*i):(mini_batch_size*(i+1))]
                self.update_mini_batch((x_mini_batch, y_mini_batch), eta, momentum, l2)
            if test_data:
                print("Epoch: {0}, Accuracy: {1}".format(j, self.evaluate((x_test, y_test))))
            else:
                print("Epoch: {0}".format(j))


network = Network([784,30,10])
network.SGD((x_train, y_train), epochs=100, mini_batch_size=100, eta=0.3, momentum=0.9, l2=0.00001, test_data=(x_test, y_test))
# Out:
# Epoch: 0, Accuracy: 0.3882
# Epoch: 1, Accuracy: 0.465
# Epoch: 2, Accuracy: 0.631
# Epoch: 3, Accuracy: 0.6519
# Epoch: 4, Accuracy: 0.6699
# Epoch: 5, Accuracy: 0.7085
# Epoch: 6, Accuracy: 0.7217
# Epoch: 7, Accuracy: 0.729
# Epoch: 8, Accuracy: 0.7323
# Epoch: 9, Accuracy: 0.735
# Epoch: 10, Accuracy: 0.7389
# Epoch: 11, Accuracy: 0.7406
# Epoch: 12, Accuracy: 0.7424
# Epoch: 13, Accuracy: 0.7437
# Epoch: 14, Accuracy: 0.7451
# Epoch: 15, Accuracy: 0.7469
# Epoch: 16, Accuracy: 0.7476
# Epoch: 17, Accuracy: 0.7483
# Epoch: 18, Accuracy: 0.7489
# Epoch: 19, Accuracy: 0.7495
# Epoch: 20, Accuracy: 0.7507
# Epoch: 21, Accuracy: 0.7529
# Epoch: 22, Accuracy: 0.8201
# Epoch: 23, Accuracy: 0.8423
# Epoch: 24, Accuracy: 0.8444
# Epoch: 25, Accuracy: 0.8453
# Epoch: 26, Accuracy: 0.8461
# Epoch: 27, Accuracy: 0.8469
# Epoch: 28, Accuracy: 0.8477
# Epoch: 29, Accuracy: 0.848
# Epoch: 30, Accuracy: 0.8478
# Epoch: 31, Accuracy: 0.8485
# Epoch: 32, Accuracy: 0.8495
# Epoch: 33, Accuracy: 0.8497
# Epoch: 34, Accuracy: 0.8501
# Epoch: 35, Accuracy: 0.8503
# Epoch: 36, Accuracy: 0.8506
# Epoch: 37, Accuracy: 0.8511
# Epoch: 38, Accuracy: 0.8512
# Epoch: 39, Accuracy: 0.8514
# Epoch: 40, Accuracy: 0.8515
# Epoch: 41, Accuracy: 0.852
# Epoch: 42, Accuracy: 0.8521
# Epoch: 43, Accuracy: 0.8525
# Epoch: 44, Accuracy: 0.8524
# Epoch: 45, Accuracy: 0.8531
# Epoch: 46, Accuracy: 0.8534
# Epoch: 47, Accuracy: 0.8537
# Epoch: 48, Accuracy: 0.854
# Epoch: 49, Accuracy: 0.8579
# Epoch: 50, Accuracy: 0.9445
# Epoch: 51, Accuracy: 0.9464
# Epoch: 52, Accuracy: 0.9474
# Epoch: 53, Accuracy: 0.9477
# Epoch: 54, Accuracy: 0.9479
# Epoch: 55, Accuracy: 0.9484
# Epoch: 56, Accuracy: 0.9486
# Epoch: 57, Accuracy: 0.9493
# Epoch: 58, Accuracy: 0.9495
# Epoch: 59, Accuracy: 0.9497
# Epoch: 60, Accuracy: 0.9506
# Epoch: 61, Accuracy: 0.951
# Epoch: 62, Accuracy: 0.9511
# Epoch: 63, Accuracy: 0.9512
# Epoch: 64, Accuracy: 0.9514
# Epoch: 65, Accuracy: 0.9519
# Epoch: 66, Accuracy: 0.9519
# Epoch: 67, Accuracy: 0.9519
# Epoch: 68, Accuracy: 0.9524
# Epoch: 69, Accuracy: 0.9523
# Epoch: 70, Accuracy: 0.9526
# Epoch: 71, Accuracy: 0.9527
# Epoch: 72, Accuracy: 0.9531
# Epoch: 73, Accuracy: 0.9532
# Epoch: 74, Accuracy: 0.9531
# Epoch: 75, Accuracy: 0.9535
# Epoch: 76, Accuracy: 0.9539
# Epoch: 77, Accuracy: 0.9542
# Epoch: 78, Accuracy: 0.9543
# Epoch: 79, Accuracy: 0.9542
# Epoch: 80, Accuracy: 0.9547
# Epoch: 81, Accuracy: 0.9552
# Epoch: 82, Accuracy: 0.9556
# Epoch: 83, Accuracy: 0.9554
# Epoch: 84, Accuracy: 0.9557
# Epoch: 85, Accuracy: 0.9556
# Epoch: 86, Accuracy: 0.9559
# Epoch: 87, Accuracy: 0.9559
# Epoch: 88, Accuracy: 0.956
# Epoch: 89, Accuracy: 0.956
# Epoch: 90, Accuracy: 0.9564
# Epoch: 91, Accuracy: 0.9565
# Epoch: 92, Accuracy: 0.9566
# Epoch: 93, Accuracy: 0.9568
# Epoch: 94, Accuracy: 0.9571
# Epoch: 95, Accuracy: 0.9571
# Epoch: 96, Accuracy: 0.9573
# Epoch: 97, Accuracy: 0.9572
# Epoch: 98, Accuracy: 0.9574
# Epoch: 99, Accuracy: 0.9577

# %%
network = Network([784,100,30,10])
network.SGD((x_train, y_train), epochs=100, mini_batch_size=100, eta=0.3, momentum=0.9, l2=0.00001, test_data=(x_test, y_test))
# Out:
# Epoch: 0, Accuracy: 0.4899
# Epoch: 1, Accuracy: 0.5402
# Epoch: 2, Accuracy: 0.5548
# Epoch: 3, Accuracy: 0.5629
# Epoch: 4, Accuracy: 0.5664
# Epoch: 5, Accuracy: 0.5686
# Epoch: 6, Accuracy: 0.5715
# Epoch: 7, Accuracy: 0.5732
# Epoch: 8, Accuracy: 0.5751
# Epoch: 9, Accuracy: 0.5755
# Epoch: 10, Accuracy: 0.5767
# Epoch: 11, Accuracy: 0.5795
# Epoch: 12, Accuracy: 0.6554
# Epoch: 13, Accuracy: 0.6618
# Epoch: 14, Accuracy: 0.6643
# Epoch: 15, Accuracy: 0.6653
# Epoch: 16, Accuracy: 0.755
# Epoch: 17, Accuracy: 0.7577
# Epoch: 18, Accuracy: 0.7597
# Epoch: 19, Accuracy: 0.7611
# Epoch: 20, Accuracy: 0.7617
# Epoch: 21, Accuracy: 0.7622
# Epoch: 22, Accuracy: 0.7627
# Epoch: 23, Accuracy: 0.7639
# Epoch: 24, Accuracy: 0.7636
# Epoch: 25, Accuracy: 0.7637
# Epoch: 26, Accuracy: 0.7642
# Epoch: 27, Accuracy: 0.7647
# Epoch: 28, Accuracy: 0.765
# Epoch: 29, Accuracy: 0.7651
# Epoch: 30, Accuracy: 0.7651
# Epoch: 31, Accuracy: 0.7652
# Epoch: 32, Accuracy: 0.766
# Epoch: 33, Accuracy: 0.7664
# Epoch: 34, Accuracy: 0.8521
# Epoch: 35, Accuracy: 0.8539
# Epoch: 36, Accuracy: 0.8562
# Epoch: 37, Accuracy: 0.8571
# Epoch: 38, Accuracy: 0.8578
# Epoch: 39, Accuracy: 0.8587
# Epoch: 40, Accuracy: 0.8593
# Epoch: 41, Accuracy: 0.8597
# Epoch: 42, Accuracy: 0.8602
# Epoch: 43, Accuracy: 0.8601
# Epoch: 44, Accuracy: 0.8605
# Epoch: 45, Accuracy: 0.8601
# Epoch: 46, Accuracy: 0.8603
# Epoch: 47, Accuracy: 0.8606
# Epoch: 48, Accuracy: 0.861
# Epoch: 49, Accuracy: 0.8612
# Epoch: 50, Accuracy: 0.8616
# Epoch: 51, Accuracy: 0.8618
# Epoch: 52, Accuracy: 0.862
# Epoch: 53, Accuracy: 0.8622
# Epoch: 54, Accuracy: 0.8621
# Epoch: 55, Accuracy: 0.8621
# Epoch: 56, Accuracy: 0.8622
# Epoch: 57, Accuracy: 0.8622
# Epoch: 58, Accuracy: 0.9213
# Epoch: 59, Accuracy: 0.9546
# Epoch: 60, Accuracy: 0.9571
# Epoch: 61, Accuracy: 0.9573
# Epoch: 62, Accuracy: 0.9579
# Epoch: 63, Accuracy: 0.9583
# Epoch: 64, Accuracy: 0.9585
# Epoch: 65, Accuracy: 0.9584
# Epoch: 66, Accuracy: 0.9587
# Epoch: 67, Accuracy: 0.9589
# Epoch: 68, Accuracy: 0.959
# Epoch: 69, Accuracy: 0.9594
# Epoch: 70, Accuracy: 0.9597
# Epoch: 71, Accuracy: 0.96
# Epoch: 72, Accuracy: 0.96
# Epoch: 73, Accuracy: 0.9603
# Epoch: 74, Accuracy: 0.9606
# Epoch: 75, Accuracy: 0.9608
# Epoch: 76, Accuracy: 0.961
# Epoch: 77, Accuracy: 0.961
# Epoch: 78, Accuracy: 0.9612
# Epoch: 79, Accuracy: 0.9613
# Epoch: 80, Accuracy: 0.9616
# Epoch: 81, Accuracy: 0.9614
# Epoch: 82, Accuracy: 0.9614
# Epoch: 83, Accuracy: 0.9613
# Epoch: 84, Accuracy: 0.9613
# Epoch: 85, Accuracy: 0.9614
# Epoch: 86, Accuracy: 0.9613
# Epoch: 87, Accuracy: 0.9616
# Epoch: 88, Accuracy: 0.9617
# Epoch: 89, Accuracy: 0.962
# Epoch: 90, Accuracy: 0.9619
# Epoch: 91, Accuracy: 0.9619
# Epoch: 92, Accuracy: 0.9616
# Epoch: 93, Accuracy: 0.9618
# Epoch: 94, Accuracy: 0.9619
# Epoch: 95, Accuracy: 0.9624
# Epoch: 96, Accuracy: 0.963
# Epoch: 97, Accuracy: 0.9633
# Epoch: 98, Accuracy: 0.9635
# Epoch: 99, Accuracy: 0.9636
